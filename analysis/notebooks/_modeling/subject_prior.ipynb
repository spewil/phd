# %%
import sys
sys.path.append('../..')
sys.path.append('..')
from analysis import analysis, plot, model, collection
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline

# %%
subjects = analysis.load_subjects()

# %%
stack = analysis.load_trial_stack(0)[:9].transpose(0,1,3,2).reshape(-1,64)
stack = analysis.remove_nan_rows(stack)
C = np.cov(stack.T)
C += 1e-5

# %%
plt.imshow(C)

# %%
w = np.random.multivariate_normal(np.zeros(shape=(64,)),np.eye(64),500)
s = np.random.multivariate_normal(np.zeros(shape=(64,)),C,500)

plt.plot(w[:,0],w[:,1],"o")
plt.plot(s[:,56],s[:,5],"o")
